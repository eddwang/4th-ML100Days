# %% [markdown]
# # 作業
# - 作業目標 : 用 iris (dataset.load_iris()) 資料嘗試跑 hierarchical clustering

# %%
from sklearn import datasets
from sklearn.cluster import AgglomerativeClustering
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
iris = datasets.load_iris()
X = iris.data
y = iris.target

# %matplotlib inline

# %% [markdown]
# 載入 相關套件 並 執行 hierarchical clustering 實驗 ...

# %%
estimators = [('hc_ward', AgglomerativeClustering(n_clusters=3, linkage="ward")),
              ('hc_complete', AgglomerativeClustering(n_clusters=3, linkage="complete")),
              ('hc_average', AgglomerativeClustering(n_clusters=3, linkage="average")),
              ('',None)]

# %%
fignum = 1
titles = ['ward', 'complate', 'average','Ground Truth']

axes=[]
fig = plt.figure(fignum, figsize=(12, 9))
for i in range(1,4+1):
    axes.append(fig.add_subplot(2, 2, i, projection='3d'))
    axes[i-1].view_init(35, 90)
fig.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, wspace = 0, hspace = 0)

for name, est in estimators:
    ax = axes[fignum-1]
    if fignum == 4 :
        for name, label in [('cls0', 0),
                    ('cls1', 1),
                    ('cls2', 2)]:
            ax.text3D(X[y == label, 3].mean(),
                      X[y == label, 0].mean() + 2,
                      X[y == label, 2].mean(), name,
                      horizontalalignment='center',size=20,
                      bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
        c = np.choose(y, [1, 2, 0]).astype(np.float)
        ax.scatter(X[:, 3], X[:, 0], X[:, 2], 
                   c=c,s=30, edgecolor='k')       
    else:
        ## fit data
        est.fit(X)   
        labels = est.labels_
        c = labels.astype(np.float)
        ax.scatter(X[:, 3], X[:, 0], X[:, 2],
                   c=c,s=40, edgecolor='k')
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_title(titles[fignum - 1])
    

    fignum = fignum + 1

# %%
fignum = 1
titles = ['ward', 'complate', 'average','Ground Truth']

axes=[]
fig = plt.figure(fignum, figsize=(12, 9))
for i in range(1,4+1):
    axes.append(fig.add_subplot(2, 2, i, projection='3d'))
    axes[i-1].view_init(20,45)
fig.subplots_adjust(left = 0, bottom = 0, right = 1, top = 1, wspace = 0, hspace = 0)

for name, est in estimators:
    ax = axes[fignum-1]
    if fignum == 4 :
        for name, label in [('cls0', 0),
                    ('cls1', 1),
                    ('cls2', 2)]:
            ax.text3D(X[y == label, 3].mean(),
                      X[y == label, 0].mean() + 2,
                      X[y == label, 2].mean(), name,
                      horizontalalignment='center',size=20,
                      bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
        c = np.choose(y, [1, 2, 0]).astype(np.float)
        ax.scatter(X[:, 3], X[:, 0], X[:, 2], 
                   c=c,s=70, edgecolor='k')       
    else:
        ## fit data
        est.fit(X)   
        labels = est.labels_
        c = labels.astype(np.float)
        ax.scatter(X[:, 3], X[:, 0], X[:, 2],
                   c=c,s=70, edgecolor='k')
    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_title(titles[fignum - 1])
    

    fignum = fignum + 1
